# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilgupta001/WheatDetection/blob/master/YOLOv5_train_Kaggle_Wheat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
from tqdm.auto import tqdm
import shutil

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %%
# !pip install -r yolov5/requirements.txt

# %%
df = pd.read_csv('/content/drive/My Drive/wheat_detection_kaggle/train.csv')
print(df.shape)
# Out:
# (147793, 5)

# %%
bboxs = np.stack(df['bbox'].apply(lambda x: np.fromstring(x[1:-1], sep = ',')))
for i, column in enumerate(['x', 'y', 'w', 'h']):
  df[column] = bboxs[:, i]
df.drop(columns = ['bbox'], inplace = True)
df['x_center'] = df['x'] + df['w'] / 2
df['y_center'] = df['y'] + df['h'] / 2
df['classes'] = 0

# %%
df = df[['image_id', 'x', 'y', 'w', 'h', 'x_center', 'y_center', 'classes']]

# %%
df
# Out:
#          image_id      x      y      w      h  x_center  y_center  classes
# 0       b6ab77fd7  834.0  222.0   56.0   36.0     862.0     240.0        0
# 1       b6ab77fd7  226.0  548.0  130.0   58.0     291.0     577.0        0
# 2       b6ab77fd7  377.0  504.0   74.0  160.0     414.0     584.0        0
# 3       b6ab77fd7  834.0   95.0  109.0  107.0     888.5     148.5        0
# 4       b6ab77fd7   26.0  144.0  124.0  117.0      88.0     202.5        0
# ...           ...    ...    ...    ...    ...       ...       ...      ...
# 147788  5e0747034   64.0  619.0   84.0   95.0     106.0     666.5        0
# 147789  5e0747034  292.0  549.0  107.0   82.0     345.5     590.0        0
# 147790  5e0747034  134.0  228.0  141.0   71.0     204.5     263.5        0
# 147791  5e0747034  430.0   13.0  184.0   79.0     522.0      52.5        0
# 147792  5e0747034  875.0  740.0   94.0   61.0     922.0     770.5        0
#
# [147793 rows x 8 columns]

# %%
index = list(set(df.image_id))

# %%
# source = 'train'
# if True:
#   for fold in [0]:
#     val_index = index[len(index) * fold//5:len(index) * (fold + 1)//5]
#     for name, mini in tqdm(df.groupby('image_id')):
#       if name in val_index:
#         path2save = 'validation/'
#       else:
#         path2save = 'train_2017/'
#       if not os.path.exists('/content/drive/My Drive/wheat_detection_kaggle/labels/' + path2save):
#         os.makedirs('/content/drive/My Drive/wheat_detection_kaggle/labels/' + path2save)
#       if not os.path.exists('/content/drive/My Drive/wheat_detection_kaggle/labels/' + path2save + name +".txt"):
#         with open('/content/drive/My Drive/wheat_detection_kaggle/labels/' + path2save + name + ".txt", 'w+') as f:
#           row = mini[['classes', 'x_center', 'y_center', 'w', 'h']].astype(float).values
#           row = row / 1024
#           row = row.astype(str)
#           for j in range(len(row)):
#             text = ' '.join(row[j])
#             f.write(text)
#             f.write("\n")
#       if not os.path.exists('/content/drive/My Drive/wheat_detection_kaggle/images/' + path2save):
#         os.makedirs('/content/drive/My Drive/wheat_detection_kaggle/images/' + path2save)
#       if not os.path.exists('/content/drive/My Drive/wheat_detection_kaggle/images/' +  path2save + name + '.jpg'):
#         shutil.copy('/content/drive/My Drive/wheat_detection_kaggle/train/' + name + ".jpg", '/content/drive/My Drive/wheat_detection_kaggle/images/' +  path2save + name + '.jpg')

# %%
# !git clone https://github.com/NVIDIA/apex && cd apex && pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" . --user && cd .. && rm -rf apex
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 7335, done.
# remote: Total 7335 (delta 0), reused 0 (delta 0), pack-reused 7335
# Receiving objects: 100% (7335/7335), 13.88 MiB | 7.04 MiB/s, done.
# Resolving deltas: 100% (4956/4956), done.
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Created temporary directory: /tmp/pip-ephem-wheel-cache-eo81mdh9
# Created temporary directory: /tmp/pip-req-tracker-p8un5e1r
# Created requirements tracker '/tmp/pip-req-tracker-p8un5e1r'
# Created temporary directory: /tmp/pip-install-dw4hnpp5
# Processing /content/apex
#   Created temporary directory: /tmp/pip-req-build-54mo093g
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-p8un5e1r'
# ...

# %%
# %%bash
# cd /content/yolov5/

# %%
# !python /content/yolov5/train.py --img 1024 --batch 2 --epochs 15 --data "/content/drive/My Drive/wheat_detection_kaggle/wheat0.yaml" --cfg "/content/drive/My Drive/wheat_detection_kaggle/yolov5xx.yaml" --name yolov5x_fold0 --weights '/content/drive/My Drive/new/last.pt'
# Out:
# Namespace(batch_size=2, bucket='', cache_images=False, cfg='/content/drive/My Drive/wheat_detection_kaggle/yolov5xx.yaml', data='/content/drive/My Drive/wheat_detection_kaggle/wheat0.yaml', device='', epochs=15, evolve=False, hyp='', img_size=[1024], multi_scale=False, name='yolov5x_fold0', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='/content/drive/My Drive/new/last.pt')
# Using CUDA Apex device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-07-15 09:10:27.462152: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# ...
